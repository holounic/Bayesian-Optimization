# %%
import pandas as pd

# %%
f_name = 'f8'

# %%
cma_es = pd.read_csv(f'{f_name}_cma_es_doe.csv')[['precision', 'f_s']].rename(columns={'precision': 'cma_es_precision'})
cma_es_init = pd.read_csv(f'{f_name}_lhs_initial_doe.csv')[['precision', 'f_s']].rename(columns={'precision': 'lhs_init_precision'})
uniform = pd.read_csv(f'uniform_doe_{f_name}.csv')[['precision', 'f_s']].rename(columns={'precision': 'uniform_precision'})
lhs = pd.read_csv(f'lhs_doe_{f_name}.csv')[['precision', 'f_s']].rename(columns={'precision': 'lhs_precision'})
halton = pd.read_csv(f'halton_doe_{f_name}.csv')[['precision', 'f_s']].rename(columns={'precision': 'halton_precision'})
sobol = pd.read_csv(f'sobol_doe_{f_name}.csv')[['precision', 'f_s']].rename(columns={'precision': 'sobol_precision'})
stats = cma_es.merge(uniform.merge(lhs.merge(sobol.merge(halton.merge(cma_es_init)))))
stats.head()
# Out:
#    cma_es_precision  f_s  uniform_precision  lhs_precision  sobol_precision  \
# 0      2.201521e+10    0       2.205428e+10   2.194078e+10     2.172392e+10
# 1      1.106337e+09    1       1.103796e+09   1.079497e+09     1.139742e+09
# 2      3.756007e+10    2       3.787107e+10   3.778214e+10     3.727692e+10
# 3      2.916640e+09    3       2.797103e+09   2.825927e+09     2.864686e+09
# 4      1.577420e+09    4       1.588417e+09   1.527022e+09     1.547388e+09
#
#    halton_precision  lhs_init_precision
# 0      2.197283e+10        2.237823e+10
# 1      1.070499e+09        1.143927e+09
# 2      3.805797e+10        3.732101e+10
# 3      2.916075e+09        2.756459e+09
# 4      1.505089e+09        1.552392e+09

# %% [markdown]
# # CMA-ES vs first individual (generated by LHS)

# %%
cma_init = stats.loc[stats['cma_es_precision'] < stats['lhs_init_precision']]
print(f'CMA-ES improved lhs-generated DoE on {cma_init.shape[0]}, ({100 * cma_init.shape[0] / stats.shape[0]}%) function instances')
cma_init[['f_s', 'cma_es_precision', 'lhs_init_precision']]
# Out:
# CMA-ES improved lhs-generated DoE on 27, (54.0%) function instances
#     f_s  cma_es_precision  lhs_init_precision
# 0     0      2.201521e+10        2.237823e+10
# 1     1      1.106337e+09        1.143927e+09
# 5     5      1.628816e+09        1.663573e+09
# 8     8      3.132833e+10        3.135919e+10
# 11   11      2.515079e+09        2.516405e+09
# 12   12      9.732755e+09        9.787552e+09
# 16   16      9.116794e+09        9.241906e+09
# 17   17      1.617203e+10        1.665220e+10
# 19   19      6.100868e+08        6.505256e+08
# 20   20      1.007175e+10        1.040287e+10
# 21   21      5.240517e+08        5.503627e+08
# 26   26      7.620780e+08        8.301038e+08
# 27   27      1.823989e+10        1.824867e+10
# 30   30      3.418438e+09        3.618360e+09
# 31   31      4.612902e+08        4.910945e+08
# 32   32      2.229388e+09        2.296103e+09
# 34   34      4.478168e+08        4.760834e+08
# 35   35      6.079039e+09        6.244246e+09
# 36   36      1.260394e+10        1.270014e+10
# 37   37      3.769082e+08        3.816082e+08
# 38   38      4.028320e+10        4.055051e+10
# 39   39      3.416114e+10        3.453746e+10
# 41   41      5.427070e+09        5.559502e+09
# 43   43      5.867847e+08        5.887861e+08
# 44   44      2.714188e+09        2.733858e+09
# 46   46      9.063470e+09        9.376652e+09
# 48   48      1.028880e+09        1.076189e+09

# %% [markdown]
# # CMA-ES generated vs Uniform

# %%
cma_uniform = stats.loc[stats['cma_es_precision'] < stats['uniform_precision']]
print(f'DoE generated by CMA-ES is better than uniformly sampled DoE on {cma_uniform.shape[0]}, ({100 * cma_uniform.shape[0] / stats.shape[0]}%) function instances')
cma_uniform[['f_s', 'cma_es_precision', 'uniform_precision']]
# Out:
# DoE generated by CMA-ES is better than uniformly sampled DoE on 27, (54.0%) function instances
#     f_s  cma_es_precision  uniform_precision
# 0     0      2.201521e+10       2.205428e+10
# 2     2      3.756007e+10       3.787107e+10
# 4     4      1.577420e+09       1.588417e+09
# 5     5      1.628816e+09       1.686098e+09
# 7     7      1.104923e+09       1.145247e+09
# 8     8      3.132833e+10       3.160841e+10
# 11   11      2.515079e+09       2.594217e+09
# 12   12      9.732755e+09       9.796141e+09
# 15   15      5.332222e+08       5.445703e+08
# 16   16      9.116794e+09       9.270789e+09
# 17   17      1.617203e+10       1.652955e+10
# 19   19      6.100868e+08       6.577910e+08
# 20   20      1.007175e+10       1.019410e+10
# 21   21      5.240517e+08       5.586947e+08
# 22   22      3.744045e+10       3.775901e+10
# 23   23      1.570859e+09       1.592404e+09
# 26   26      7.620780e+08       8.178352e+08
# 30   30      3.418438e+09       3.638083e+09
# 34   34      4.478168e+08       4.731594e+08
# 35   35      6.079039e+09       6.252879e+09
# 37   37      3.769082e+08       3.835660e+08
# 39   39      3.416114e+10       3.481246e+10
# 41   41      5.427070e+09       5.574068e+09
# 43   43      5.867847e+08       6.002400e+08
# 44   44      2.714188e+09       2.769662e+09
# 45   45      3.581108e+09       3.653049e+09
# 47   47      1.326225e+10       1.355402e+10

# %% [markdown]
# # CMA-ES vs LHS

# %%
cma_lhs = stats.loc[stats['cma_es_precision'] < stats['lhs_precision']]
print(f'DoE generated by CMA-ES is better than lhs sampled DoE on {cma_lhs.shape[0]} ({100 * cma_lhs.shape[0] / stats.shape[0]}%) function instances')
cma_lhs[['f_s', 'cma_es_precision', 'lhs_precision']]
# Out:
# DoE generated by CMA-ES is better than lhs sampled DoE on 22 (44.0%) function instances
#     f_s  cma_es_precision  lhs_precision
# 2     2      3.756007e+10   3.778214e+10
# 5     5      1.628816e+09   1.724222e+09
# 6     6      8.149686e+09   8.470126e+09
# 8     8      3.132833e+10   3.143200e+10
# 11   11      2.515079e+09   2.590838e+09
# 13   13      8.112192e+08   8.147226e+08
# 15   15      5.332222e+08   5.565072e+08
# 16   16      9.116794e+09   9.441883e+09
# 17   17      1.617203e+10   1.636516e+10
# 19   19      6.100868e+08   6.321175e+08
# 20   20      1.007175e+10   1.021877e+10
# 23   23      1.570859e+09   1.580281e+09
# 26   26      7.620780e+08   8.179844e+08
# 30   30      3.418438e+09   3.571732e+09
# 32   32      2.229388e+09   2.262580e+09
# 33   33      9.237522e+09   9.659805e+09
# 34   34      4.478168e+08   4.857165e+08
# 35   35      6.079039e+09   6.246119e+09
# 37   37      3.769082e+08   3.914444e+08
# 39   39      3.416114e+10   3.453253e+10
# 41   41      5.427070e+09   5.526518e+09
# 48   48      1.028880e+09   1.037873e+09

# %% [markdown]
# # CMA-ES vs Sobol

# %%
cma_sobol = stats.loc[stats['cma_es_precision'] < stats['sobol_precision']]
print(f'DoE generated by CMA-ES is better than sobol generated DoE on {cma_sobol.shape[0]} ({100 * cma_sobol.shape[0] / stats.shape[0]}%) function instances')
cma_sobol[['f_s', 'cma_es_precision', 'sobol_precision']]
# Out:
# DoE generated by CMA-ES is better than sobol generated DoE on 23 (46.0%) function instances
#     f_s  cma_es_precision  sobol_precision
# 1     1      1.106337e+09     1.139742e+09
# 5     5      1.628816e+09     1.716949e+09
# 7     7      1.104923e+09     1.147516e+09
# 8     8      3.132833e+10     3.142376e+10
# 10   10      7.010092e+08     7.028131e+08
# 12   12      9.732755e+09     9.757355e+09
# 16   16      9.116794e+09     9.190095e+09
# 17   17      1.617203e+10     1.632902e+10
# 20   20      1.007175e+10     1.030316e+10
# 23   23      1.570859e+09     1.591071e+09
# 25   25      7.220895e+08     7.285375e+08
# 26   26      7.620780e+08     7.936060e+08
# 28   28      4.620242e+09     4.859792e+09
# 30   30      3.418438e+09     3.568580e+09
# 33   33      9.237522e+09     9.435444e+09
# 34   34      4.478168e+08     4.828158e+08
# 35   35      6.079039e+09     6.148613e+09
# 37   37      3.769082e+08     4.051458e+08
# 39   39      3.416114e+10     3.528491e+10
# 41   41      5.427070e+09     5.667245e+09
# 44   44      2.714188e+09     2.735540e+09
# 47   47      1.326225e+10     1.358454e+10
# 48   48      1.028880e+09     1.077714e+09

# %% [markdown]
# # CMA-ES vs Halton

# %%
cma_halton = stats.loc[stats['cma_es_precision'] < stats['halton_precision']]
print(f'DoE generated by CMA-ES is better than halton generated DoE on {cma_halton.shape[0]} ({100 * cma_halton.shape[0] / stats.shape[0]}%) function instances')
cma_halton[['f_s', 'cma_es_precision', 'halton_precision']]
# Out:
# DoE generated by CMA-ES is better than halton generated DoE on 26 (52.0%) function instances
#     f_s  cma_es_precision  halton_precision
# 2     2      3.756007e+10      3.805797e+10
# 5     5      1.628816e+09      1.742316e+09
# 6     6      8.149686e+09      8.410700e+09
# 7     7      1.104923e+09      1.105037e+09
# 11   11      2.515079e+09      2.531259e+09
# 13   13      8.112192e+08      8.241756e+08
# 16   16      9.116794e+09      9.125574e+09
# 17   17      1.617203e+10      1.647833e+10
# 19   19      6.100868e+08      6.351715e+08
# 20   20      1.007175e+10      1.010330e+10
# 21   21      5.240517e+08      5.507023e+08
# 24   24      1.268783e+09      1.273100e+09
# 25   25      7.220895e+08      7.232385e+08
# 26   26      7.620780e+08      8.002724e+08
# 30   30      3.418438e+09      3.514944e+09
# 31   31      4.612902e+08      4.703535e+08
# 32   32      2.229388e+09      2.324341e+09
# 33   33      9.237522e+09      9.477248e+09
# 34   34      4.478168e+08      4.857367e+08
# 35   35      6.079039e+09      6.401312e+09
# 37   37      3.769082e+08      3.931850e+08
# 39   39      3.416114e+10      3.489074e+10
# 41   41      5.427070e+09      5.591778e+09
# 43   43      5.867847e+08      5.981225e+08
# 47   47      1.326225e+10      1.363707e+10
# 48   48      1.028880e+09      1.038915e+09

# %%
cma_is_best = stats.loc[(stats['cma_es_precision'] < stats['halton_precision']) & (stats['cma_es_precision'] < stats['uniform_precision']) & (stats['cma_es_precision'] < stats['lhs_precision']) & (stats['cma_es_precision'] < stats['sobol_precision'])]
print(f'DoE generated by CMA-ES is better than any baseline generated DoE on {cma_is_best.shape[0]} ({100 * cma_is_best.shape[0] / stats.shape[0]}%) function instances')
cma_is_best
# Out:
# DoE generated by CMA-ES is better than any baseline generated DoE on 11 (22.0%) function instances
#     cma_es_precision  f_s  uniform_precision  lhs_precision  sobol_precision  \
# 5       1.628816e+09    5       1.686098e+09   1.724222e+09     1.716949e+09
# 16      9.116794e+09   16       9.270789e+09   9.441883e+09     9.190095e+09
# 17      1.617203e+10   17       1.652955e+10   1.636516e+10     1.632902e+10
# 20      1.007175e+10   20       1.019410e+10   1.021877e+10     1.030316e+10
# 26      7.620780e+08   26       8.178352e+08   8.179844e+08     7.936060e+08
# 30      3.418438e+09   30       3.638083e+09   3.571732e+09     3.568580e+09
# 34      4.478168e+08   34       4.731594e+08   4.857165e+08     4.828158e+08
# 35      6.079039e+09   35       6.252879e+09   6.246119e+09     6.148613e+09
# 37      3.769082e+08   37       3.835660e+08   3.914444e+08     4.051458e+08
# 39      3.416114e+10   39       3.481246e+10   3.453253e+10     3.528491e+10
# 41      5.427070e+09   41       5.574068e+09   5.526518e+09     5.667245e+09
#
#     halton_precision  lhs_init_precision
# 5       1.742316e+09        1.663573e+09
# 16      9.125574e+09        9.241906e+09
# 17      1.647833e+10        1.665220e+10
# 20      1.010330e+10        1.040287e+10
# 26      8.002724e+08        8.301038e+08
# 30      3.514944e+09        3.618360e+09
# 34      4.857367e+08        4.760834e+08
# 35      6.401312e+09        6.244246e+09
# 37      3.931850e+08        3.816082e+08
# 39      3.489074e+10        3.453746e+10
# 41      5.591778e+09        5.559502e+09
